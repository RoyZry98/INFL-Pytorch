# %%
import os, sys

PROJECT_ROOT = "/deltadisk/zhangrongyu/leo/INFL-Pytorch/multi-omics_intergation"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

os.environ['R_HOME'] = '/deltadisk/miniconda3/envs/SpaMosaic/lib/R'
os.environ['R_USER'] = '/deltadisk/miniconda3/envs/SpaMosaic/lib/python3.8/site-packages/rpy2'
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'

from src.pipeline_utils import run_and_save_mm

import json
from pprint import pprint

print("Imports OK.")
# Out:
# Imports OK.

# %%
result = run_and_save_mm(
    data_dir='/deltadisk/zhangrongyu/SpaMosaic/data/integration/Human_tonsil',
    device='cuda:0',
    num_rounds=50,
    local_epochs=2,
    learning_rate=1e-3,
    inr=True,              # Change to True when using INFL
    inr_hidden_size=16,
    run_name=None,
    seed=1234,
)
print("Training finished.")
# Out:
# Use GPU mode.
# 	Initialization is completed.
# 	Completed 1 / 10 iteration(s).
# 	Completed 2 / 10 iteration(s).
# 	Completed 3 / 10 iteration(s).
# 	Completed 4 / 10 iteration(s).
# 	Completed 5 / 10 iteration(s).
# Reach convergence after 5 iteration(s).
# Use GPU mode.
# 	Initialization is completed.
# 	Completed 1 / 10 iteration(s).
# 	Completed 2 / 10 iteration(s).
# 	Completed 3 / 10 iteration(s).
# Reach convergence after 3 iteration(s).
# --- Round 1/50 ---
# Training on client 1...
# 100%|██████████| 2/2 [00:00<00:00,  4.64it/s]
# Loss: 72.30335998535156
# Training on client 2...
# 100%|██████████| 2/2 [00:00<00:00, 37.86it/s]
# Loss: 72.46209716796875
# Training on client 3...
# 100%|██████████| 2/2 [00:00<00:00, 34.93it/s]
# Loss: 73.10151672363281
# Average loss for round 1: 72.62232462565105
# New best model found with loss: 72.62232462565105
# --- Round 2/50 ---
# Training on client 1...
# 100%|██████████| 2/2 [00:00<00:00, 42.33it/s]
# Loss: 49.97922897338867
# ...

# %%
print('Best loss:', result['best_loss'])
print('Embeddings H5AD:', result['merged_embeddings_path'])
print('Loss CSV:', result['loss_csv_path'])
print('Loss curve PNG:', result['loss_curve_path'])
print('Param report JSON:', result['param_report_path'])
# Out:
# Best loss: 5.024317900339763
# Embeddings H5AD: ./tonsil_output_embeddings/merged_embeddings_inr_True.h5ad
# Loss CSV: ./tonsil_logs/loss_history_inr_True.csv
# Loss curve PNG: ./figure/fed_loss_curve_inr_True.png
# Param report JSON: ./tonsil_logs/param_report_inr_True.json
