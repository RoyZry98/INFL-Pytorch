# %% [markdown]
# 1. Import path and variables

# %%
from pathlib import Path
import sys

TASK_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'tutorial' else Path.cwd().resolve()
SRC_DIR = TASK_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

from pipeline_utils import TrainingConfig, build_training_command, run_training

print('TASK_ROOT =', TASK_ROOT)

# %% [markdown]
# 2. Set hyperparameters

# %%
config = TrainingConfig(
    out_dir='spatial_fed_e5_c30_fixedsplit_stable',
    methods='normal,dp,ppml,inr',
    epochs=5,
    clients=30,
    batch_size=16,
    eval_batch_size=64,
    num_workers=4,
    lr=1e-5,
    epsilon=10,
    delta=1e-3,
    l2_clip=1,
    key_strength=1.0,
)
print(' '.join(build_training_command(config)))

# %% [markdown]
# 3. Start training

# %%
RUN_TRAINING = False
if RUN_TRAINING:
    run_training(config)
